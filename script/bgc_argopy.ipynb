# %%
import argopy

with argopy.set_options(ds='bgc'):
 ds = argopy.DataFetcher().region([, 0, 300, '2024-01', '2025-01']).to_xarray()
# Out:
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\lib\site-packages\argopy\data_fetchers\erddap_data.py:734, in ErddapArgoDataFetcher.to_xarray(self, errors, add_dm, concat, max_workers)
#     732 try:
#     733     # log_argopy_callerstack()
# --> 734     results = self.fs.open_dataset(URI[0])
#     735     results = pre_process(results, **preprocess_opts)
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\lib\site-packages\argopy\stores\filesystems.py:799, in httpstore.open_dataset(self, url, errors, **kwargs)
#     798     dwn_opts.update(kwargs["dwn_opts"])
# --> 799 data = self.download_url(url, **dwn_opts)
#     801 if data is None:
#
# ...
