# %% [markdown]
# # Compute a NC Databse for OG1 gliders data

# %%
import sys
sys.path.append('C:/Users/flapet/OneDrive - NOC/Documents/utils_python')
from functions.profiling import *
from functions.general import *
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

#Set relative path
os.chdir("C:/Users/flapet/OneDrive - NOC/Documents/IDAPro/lib/db_building/")

dataset_dir = "data/glider/OG1/"

# %%
filename = dataset_dir + 'Cabot_645_R.nc'
prof = find_profiles_by_depth(filename)
dat = xr.open_dataset(filename)
# Out:
# 100%|██████████| 1090/1090 [00:01<00:00, 629.14it/s]

# %%
#Return a list of the profiles length
row_lengths = [len(arr) for arr in prof]
#Create an array of arrays filled with the number of the profiles
profile_list = np.array([np.full((length,), idx + 1) for idx, length in enumerate(row_lengths)], dtype = object)
#Flatten it into a 1D array
profile_list = np.concatenate(profile_list, axis = None)

#Go back to the profiles index to flatten it and select xarray dataset points that match a profile point
prof_flat = np.concatenate(prof, axis = None)
nc_profiles = dat.sel(N_MEASUREMENTS = prof_flat)

# %%
dat['PRES'].values
# Out:
# array([ 0., nan, nan, ..., nan, nan, nan], dtype=float32)

# %%
nc_profiles = nc_profiles.assign(profile_index=("N_MEASUREMENTS", profile_list))

# %%
#Add attributes
nc_profiles['profile_index'].attrs.update({
    'long_name': 'Index of the profile',
    'description': 'Each obs has an index that correspond to the number of the profile',
    'source': 'Profiling function from utils python',
    'processing_date': '2024-11-27'
})

# %%
nc_profiles['PRES'].values

# %%
nc_profiles.load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nc_profiles.load()
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\dataset.py:855, in Dataset.load(self, **kwargs)
#     853 for k, v in self.variables.items():
#     854     if k not in lazy_data:
# --> 855         v.load()
#     857 return self
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\variable.py:936, in Variable.load(self, **kwargs)
#     919 def load(self, **kwargs):
#     920     """Manually trigger loading of this variable's data from disk or a
#     921     remote source into memory and return this variable.
#     922
#    (...)
#     934     dask.array.compute
#     935     """
# --> 936     self._data = to_duck_array(self._data, **kwargs)
#     937     return self
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\namedarray\pycompat.py:134, in to_duck_array(data, **kwargs)
#     131     return loaded_data
#     133 if isinstance(data, ExplicitlyIndexed):
# --> 134     return data.get_duck_array()  # type: ignore[no-untyped-call, no-any-return]
#     135 elif is_duck_array(data):
#     136     return data
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:696, in MemoryCachedArray.get_duck_array(self)
#     695 def get_duck_array(self):
# --> 696     self._ensure_cached()
#     697     return self.array.get_duck_array()
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:690, in MemoryCachedArray._ensure_cached(self)
#     689 def _ensure_cached(self):
# --> 690     self.array = as_indexable(self.array.get_duck_array())
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:664, in CopyOnWriteArray.get_duck_array(self)
#     663 def get_duck_array(self):
# --> 664     return self.array.get_duck_array()
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:557, in LazilyIndexedArray.get_duck_array(self)
#     552 # self.array[self.key] is now a numpy array when
#     553 # self.array is a BackendArray subclass
#     554 # and self.key is BasicIndexer((slice(None, None, None),))
#     555 # so we need the explicit check for ExplicitlyIndexed
#     556 if isinstance(array, ExplicitlyIndexed):
# --> 557     array = array.get_duck_array()
#     558 return _wrap_numpy_scalars(array)
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\coding\variables.py:75, in _ElementwiseFunctionArray.get_duck_array(self)
#      74 def get_duck_array(self):
# ---> 75     return self.func(self.array.get_duck_array())
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:551, in LazilyIndexedArray.get_duck_array(self)
#     550 def get_duck_array(self):
# --> 551     array = self.array[self.key]
#     552     # self.array[self.key] is now a numpy array when
#     553     # self.array is a BackendArray subclass
#     554     # and self.key is BasicIndexer((slice(None, None, None),))
#     555     # so we need the explicit check for ExplicitlyIndexed
#     556     if isinstance(array, ExplicitlyIndexed):
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\backends\netCDF4_.py:101, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     100 def __getitem__(self, key):
# --> 101     return indexing.explicit_indexing_adapter(
#     102         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     103     )
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\core\indexing.py:858, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     836 """Support explicit indexing by delegating to a raw indexing method.
#     837
#     838 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     855 Indexing result, in the form of a duck numpy-array.
#     856 """
#     857 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 858 result = raw_indexing_method(raw_key.tuple)
#     859 if numpy_indices.tuple:
#     860     # index the loaded np.ndarray
#     861     result = NumpyIndexingAdapter(result)[numpy_indices]
#
# File c:\Users\flapet\OneDrive - NOC\Documents\IDAPro\lib\db_building\db_env\Lib\site-packages\xarray\backends\netCDF4_.py:114, in NetCDF4ArrayWrapper._getitem(self, key)
#     112     with self.datastore.lock:
#     113         original_array = self.get_array(needs_lock=False)
# --> 114         array = getitem(original_array, key)
#     115 except IndexError:
#     116     # Catch IndexError in netCDF4 and return a more informative
#     117     # error message.  This is most often called when an unsorted
#     118     # indexer is used before the data is loaded from disk.
#     119     msg = (
#     120         "The indexing operation you are attempting to perform "
#     121         "is not valid on netCDF4.Variable object. Try loading "
#     122         "your data into memory first by calling .load()."
#     123     )
#
# KeyboardInterrupt:

# %%
nc_profiles_grouped = nc_profiles.groupby('profile_index')

# %%
nc_profiles_grouped[165]
# Out:
# <xarray.Dataset> Size: 376kB
# Dimensions:                               (N_MEASUREMENTS: 1760, N_PARAM: 22)
# Dimensions without coordinates: N_MEASUREMENTS, N_PARAM
# Data variables: (12/64)
#     TIME                                  (N_MEASUREMENTS) datetime64[ns] 14kB ...
#     TIME_GPS                              (N_MEASUREMENTS) datetime64[ns] 14kB ...
#     PHASE                                 (N_MEASUREMENTS) float32 7kB ...
#     PHASE_QC                              (N_MEASUREMENTS) float32 7kB ...
#     PRES                                  (N_MEASUREMENTS) float32 7kB ...
#     CNDC                                  (N_MEASUREMENTS) float32 7kB ...
#     ...                                    ...
#     PLATFORM_MODEL                        <U2 8B ...
#     WMO_IDENTIFIER                        <U3 12B ...
#     DEPLOYMENT_TIME                       datetime64[ns] 8B ...
#     DEPLOYMENT_LATITUDE                   <U18 72B ...
#     DEPLOYMENT_LONGITUDE                  <U19 76B ...
#     profile_index                         (N_MEASUREMENTS) int32 7kB 165 ... 165
# Attributes: (12/68)
#     geospatial_bounds_crs:           EPSG:4326
#     geospatial_bounds_vertical_crs:  EPSG:5831
#     geospatial_lat_min:              50.89261
#     geospatial_lat_max:              62.48666
#     geospatial_lon_min:              50.89261
#     geospatial_lon_max:              62.48666
#     ...                              ...
#     instrument:                      ['SBE Slocum Glider Payload (GPCTD) CTD'...
#     metadata_link:                   https://api.linked-systems.uk/api/meta/v...
#     trajectory:                      Cabot_20240528
#     date_created:                    2024-09-26T14:34:53.791760
#     date_modified:                   2024-09-26T14:34:53.792464
#     id:                              Cabot_20240528T000000_R

# %%
chl = nc_profiles_grouped[165]['CHLA'].values
pres = nc_profiles_grouped[165]['PRES'].values

# %%
import matplotlib.pyplot as plt
chl = interp_nan(chl)
pres = interp_nan(pres)

#Simple plot
plt.plot(chl, -pres)
plt.show()

# %% [markdown]
# Basic operation n#1 - looping through profiles to interpolate and smooth te chla profiles.

# %%
# %%time

chla_smoothed = []

for prof in range(max(profile_list)):
    chla_t = nc_profiles["CHLA"].where(nc_profiles["profile_index"] == prof, drop=True)
    pres_t = nc_profiles["PRES"].where(nc_profiles["profile_index"] == prof, drop=True)

    chla_t = interp_nan(chla_t)
    pres_t = interp_nan(pres_t)

    chla_t = slide(chla_t, k = 2)

    chla_smoothed = chla_smoothed.append(chla_t)

# %%
profile_list

# %%
# dat2 = dat.assign(CHLA_ADJUSTED=lambda x: x.CHLA / 2)
# dat2['CHLA_ADJUSTED'].attrs.update({
#     'units': 'mg',
#     'description': 'Chlorophyll adjusted by dividing original CHLA by 2',
#     'source': 'ECO Puk sensor',
#     'notes': 'Data adjusted for experimental purposes',
#     'processing_date': '2024-11-21'
# })
